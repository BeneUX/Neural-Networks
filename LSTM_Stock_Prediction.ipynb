# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Trainingsdatensatz einlesen
dataset_train = pd.read_csv('statics/Google_Stock_Price_Train.csv')
dataset_train.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
# Trainingsdaten in ein einheitliches Format überführen
training_set = dataset_train.iloc[:,1:2].values

print(training_set)
print(training_set.shape)
# Out:
# [[325.25]
#  [331.27]
#  [329.83]
#  ...
#  [793.7 ]
#  [783.33]
#  [782.75]]
# (1258, 1)

# %%
# Normalisieren der Daten
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))
scaled_training_set = scaler.fit_transform(training_set)

# %%
# X und y Trainings Datenstrukturen erstellen
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(scaled_training_set[i-60:i, 0])
    y_train.append(scaled_training_set[i, 0])
X_train = np.array(X_train)
y_train = np.array(y_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (1198, 60)
# (1198,)

# %%
# Reshape der Daten
X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1], 1))

X_train.shape
# Out:
# (1198, 60, 1)

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences= True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences= True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences= True ))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 38/38 [==============================] - 8s 67ms/step - loss: 0.0408
# Epoch 2/200
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0065
# Epoch 3/200
# 38/38 [==============================] - 3s 66ms/step - loss: 0.0060
# Epoch 4/200
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0049
# Epoch 5/200
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0047
# Epoch 6/200
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0042
# Epoch 7/200
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0044
# Epoch 8/200
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0047
# Epoch 9/200
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0044
# Epoch 10/200
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0041
# Epoch 11/200
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0046
# Epoch 12/200
# ...

# %%
dataset_test = pd.read_csv("statics/Google_Stock_Price_Test.csv")
actual_stock_price = dataset_test.iloc[:,1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis=0)
inputs = dataset_total[len(dataset_total)- len(dataset_test)-60:].values

inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

X_test = []
for i in range(60,80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1], 1))

# %%
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
plt.plot(actual_stock_price, color = 'red', label = 'Tatsächlicher Google Aktienkurs')
plt.plot(predicted_stock_price, color = 'blue', label = 'Vorausgesagter Google Aktienkurs')
plt.title('Google Aktienkursprognose mit LSTM')
plt.xlabel('Zeit')
plt.ylabel('Kurswert')
plt.legend()
